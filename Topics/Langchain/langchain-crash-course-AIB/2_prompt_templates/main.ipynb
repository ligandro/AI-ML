# %%
from langchain.prompts import ChatPromptTemplate
from langchain_core.messages import HumanMessage

# PART 1: Create a ChatPromptTemplate using a template string
template = "Tell me a joke about {topic}."
prompt_template = ChatPromptTemplate.from_template(template)

print("-----Prompt from Template-----")
prompt = prompt_template.invoke({"topic": "cats"})
print(prompt)
# Out:
# -----Prompt from Template-----
# messages=[HumanMessage(content='Tell me a joke about cats.', additional_kwargs={}, response_metadata={})]

# %%
# PART 2: Prompt with Multiple Placeholders
template_multiple = """You are a helpful assistant.
Human: Tell me a {adjective} story about a {animal}.
Assistant:"""
prompt_multiple = ChatPromptTemplate.from_template(template_multiple)
prompt = prompt_multiple.invoke({"adjective": "funny", "animal": "panda"})
print("\n----- Prompt with Multiple Placeholders -----\n")
print(prompt)
# Out:
# ----- Prompt with Multiple Placeholders -----
#
# messages=[HumanMessage(content='You are a helpful assistant.\nHuman: Tell me a funny story about a panda.\nAssistant:', additional_kwargs={}, response_metadata={})]

# %%
# PART 3: Prompt with System and Human Messages (Using Tuples)
messages = [
    ("system", "You are a comedian who tells jokes about {topic}."),
    ("human", "Tell me {joke_count} jokes."),
]
prompt_template = ChatPromptTemplate.from_messages(messages)
prompt = prompt_template.invoke({"topic": "lawyers", "joke_count": 3})
print("\n----- Prompt with System and Human Messages (Tuple) -----\n")
print(prompt)
# Out:
# ----- Prompt with System and Human Messages (Tuple) -----
#
# messages=[SystemMessage(content='You are a comedian who tells jokes about lawyers.', additional_kwargs={}, response_metadata={}), HumanMessage(content='Tell me 3 jokes.', additional_kwargs={}, response_metadata={})]

# %%
# # Extra Informoation about Part 3.
# # This does work:
messages = [
    ("system", "You are a comedian who tells jokes about {topic}."),
    HumanMessage(content="Tell me 3 jokes."),
]
prompt_template = ChatPromptTemplate.from_messages(messages)
prompt = prompt_template.invoke({"topic": "lawyers"})
print("\n----- Prompt with System and Human Messages (Tuple) -----\n")
print(prompt)
# Out:
# ----- Prompt with System and Human Messages (Tuple) -----
#
# messages=[SystemMessage(content='You are a comedian who tells jokes about lawyers.', additional_kwargs={}, response_metadata={}), HumanMessage(content='Tell me 3 jokes.', additional_kwargs={}, response_metadata={})]

# %%
from langchain.prompts import ChatPromptTemplate
from langchain_openai import ChatOpenAI

from langchain_community.chat_models import ChatOllama
from langchain.schema.messages import HumanMessage

# Create a ChatOllama model (e.g., using llama3, mistral, etc.)
model = ChatOllama(model="llama3.2")  # or "mistral", "gemma", etc.

# PART 1: Create a ChatPromptTemplate using a template string
print("-----Prompt from Template-----")
template = "Tell me a joke about {topic}."
prompt_template = ChatPromptTemplate.from_template(template)

prompt = prompt_template.invoke({"topic": "cats"})
result = model.invoke(prompt)
print(result.content)
# Out:
# C:\Users\lolen\AppData\Local\Temp\ipykernel_35472\2803292142.py:8: LangChainDeprecationWarning: The class `ChatOllama` was deprecated in LangChain 0.3.1 and will be removed in 1.0.0. An updated version of the class exists in the :class:`~langchain-ollama package and should be used instead. To use it run `pip install -U :class:`~langchain-ollama` and import as `from :class:`~langchain_ollama import ChatOllama``.
#   model = ChatOllama(model="llama3.2")  # or "mistral", "gemma", etc.
# -----Prompt from Template-----
# Why did the cat join a band?
#
# Because it wanted to be the purr-cussionist! (get it?)

# %%
from pprint import pprint
# PART 2: Prompt with Multiple Placeholders
print("\n----- Prompt with Multiple Placeholders -----\n")
template_multiple = """You are a helpful assistant.
Human: Tell me a {adjective} short story about a {animal}.
Assistant:"""
prompt_multiple = ChatPromptTemplate.from_template(template_multiple)
prompt = prompt_multiple.invoke({"adjective": "funny", "animal": "panda"})

result = model.invoke(prompt)
pprint(result.content)
# Out:
# ----- Prompt with Multiple Placeholders -----
#
# ("Here's a funny short story about a panda:\n"
#  '\n'
#  'Once upon a time, in a bamboo forest in China, there lived a panda named '
#  'Ping. Ping loved to eat bamboo shoots and take long naps. One day, while he '
#  'was busy munching on some delicious bamboo, he got a bit too comfortable.\n'
#  '\n'
#  'As he sat there with his paws folded under him, Ping started to snore '
#  "loudly. But this wasn't just any ordinary snore - it sounded exactly like "
#  'the sound of a trumpet!\n'
#  '\n'
#  'A group of nearby birds, who were playing a band in a nearby tree, heard '
#  'Ping\'s trumpet-like snores and couldn\'t help but burst out laughing. "What '
#  'is that noise?" they asked each other.\n'
#  '\n'
#  'Just then, a curious rabbit hopped by and asked what all the commotion was '
#  "about. The birds told him about Ping's snoring, and the rabbit chuckled and "
#  'said, "I know who it sounds like! It\'s Ping, our sleepy panda friend!"\n'
#  '\n'
#  "The birds and the rabbit couldn't stop laughing at Ping's silly snores. From "
#  'that day on, whenever Ping took a nap, his trumpet-like snore would be '
#  'accompanied by laughter from all his forest friends.\n'
#  '\n'
#  'And Ping? Well, he just kept on snoring away, happy to be the star of the '
#  'show!')

# %%
# PART 3: Prompt with System and Human Messages (Using Tuples)
print("\n----- Prompt with System and Human Messages (Tuple) -----\n")
messages = [
    ("system", "You are a comedian who tells jokes about {topic}."),
    ("human", "Tell me {joke_count} jokes."),
]
prompt_template = ChatPromptTemplate.from_messages(messages)
prompt = prompt_template.invoke({"topic": "lawyers", "joke_count": 3})
result = model.invoke(prompt)
print(result.content)
# Out:
# ----- Prompt with System and Human Messages (Tuple) -----
#
# Here are three lawyer-themed jokes for you:
#
# 1. Why did the lawyer's client bring a ladder to court?
#
# Because they wanted to take their case to a higher level! (get it?)
#
# 2. What do you call a lawyer who doesn't eat? A law-abiding vegetarian.
#
# 3. Why did the lawyer's wife leave him? Because he was always on the witness stand – every time I asked him about something, he'd have to testify that he didn't know anything about it!

# %%
# %pip install
